# %%
import numpy as np
a = np.array([1, 2, 3, 4, 5])
print("Array:", a)
print("Mean:", np.mean(a))
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0

# %%
import pandas as pd
data = {'Name': ['A', 'B', 'C'], 'Marks': [85, 90, 88]}
df = pd.DataFrame(data)
print(df)
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     88

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 4, 6, 8, 10])
model = LinearRegression()
model.fit(X, y)
print("Prediction for 6:", model.predict([[6]]))
# Out:
# Prediction for 6: [12.]

# %%
from scipy import stats
data = [10, 20, 30, 40, 50]
print("Mean:", stats.tmean(data))
# Out:
# Mean: 30.0

# %%
import tensorflow as tf
a = tf.constant(10)
b = tf.constant(20)
print("Sum:", tf.add(a, b))
# Out:
# Sum: tf.Tensor(30, shape=(), dtype=int32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(4,)))
model.add(Dense(1))
model.summary()
# Out:
# c:\Users\Pranav Patil\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49 (196.00 B)
#  Trainable params: 49 (196.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.xlabel("x-axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Plot")
plt.show()

# %%
import seaborn as sns
import pandas as pd
data = pd.DataFrame({'x': [1, 2, 3, 4], 'y': [10, 20, 25, 30]})
sns.scatterplot(x='x', y='y', data=data)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs

# 1. Generate dataset
X, y = make_blobs(n_samples=200, centers=2, random_state=42)

# 2. Train model (EM via GMM)
model = GaussianMixture(n_components=2, random_state=42)
model.fit(X)

# 3. Predict cluster labels
y_pred = model.predict(X)

# 4. Plot
plt.figure(figsize=(6,5))
plt.scatter(X[:,0], X[:,1], c=y_pred, cmap='bwr')
plt.title("EM Algorithm (GMM Clustering)")
plt.show()
